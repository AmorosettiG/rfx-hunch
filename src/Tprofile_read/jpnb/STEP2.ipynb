# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors 
# %matplotlib notebook

import ipysh
import Dummy_g1data as dummy
import Hunch_utils  as Htls
import Hunch_lsplot as Hplt

# %aimport models.base
# %aimport models.AEFIT

INTERACTIVE = True

# %% [markdown]
# # TEST1: 3G X-strafe

# %%
ds = dummy.Dummy_g1data(counts=1000)
ds.kinds =  [
    {'mean': [0.8], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [0.5]},    
]
ds.buffer()
dummy.test_gendata(ds)
m = models.AEFIT.AEFIT(latent_dim=2, beta=0.)
# Out:
# WARNING:tensorflow:From /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Dummy_g1data.py:247: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# <img src="data:image/png;base64,..." width="639.999990463257">
# AEFIT5 ready:

# %%
if INTERACTIVE:
    p = Hplt.LSPlotBokeh()
    p.set_model(m)
    p.set_data(ds)
    p.plot(notebook_url='http://localhost:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1609">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:41501/autoload.js?bokeh-autoload-element=1610&bokeh-absolute-url=http://localhost:41501&resources=none" id="1610"></script>
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '1.040,2.176undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '2.176undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '2.176undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '1.040,2.176undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '2.176undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '2.176undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.594,1.763undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '1.763undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '1.763undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.232,1.288undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '1.288undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '1.288undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '-0.441,-0.282undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '-0.282undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '-0.282undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '-0.265,-0.954undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '-0.954undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '-0.954undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.677,-0.334undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '-0.334undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '-0.334undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.677,-0.334undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '-0.334undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '-0.334undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.801,-0.076undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '-0.076undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '-0.076undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.833,0.141undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '0.141undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '0.141undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '0.864,0.203undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '0.203undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
# ...
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '0.348undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '1.143,0.616undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '0.616undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '0.616undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '2.882,1.856undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '1.856undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '1.856undefined'
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'TextInput', 'id': '1410'}, 'attr': 'value', 'new': '3.824,2.527undefined'}], 'references': []}
#  error: ValueError("could not convert string to float: '2.527undefined'",)
# Traceback (most recent call last):
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/protocol_handler.py", line 100, in handle
#     work = yield handler(message, connection)
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1055, in run
#     value = future.result()
#   File "/usr/lib/python3/dist-packages/tornado/concurrent.py", line 238, in result
#     raise_exc_info(self._exc_info)
#   File "<string>", line 4, in raise_exc_info
#   File "/usr/lib/python3/dist-packages/tornado/gen.py", line 1069, in run
#     yielded = self.gen.send(value)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 70, in _needs_document_lock_wrapper
#     result = yield yield_for_all_futures(func(self, *args, **kwargs))
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/server/session.py", line 257, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/protocol/messages/patch_doc.py", line 107, in apply_to_document
#     doc.apply_json_patch(self.content, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 394, in apply_json_patch
#     patched_obj.set_from_json(attr, value, models=references, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/has_props.py", line 347, in set_from_json
#     descriptor.set_from_json(self, json, models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 618, in set_from_json
#     models, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 327, in set_from_json
#     self._internal_set(obj, json, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 769, in _internal_set
#     self._real_set(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 838, in _real_set
#     self._trigger(obj, old, value, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/core/property/descriptors.py", line 915, in _trigger
#     obj.trigger(self.name, old, value, hint, setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/model.py", line 717, in trigger
#     super(Model, self).trigger(attr, old, new, hint=hint, setter=setter)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 161, in trigger
#     self._document._notify_change(self, attr, old, new, hint, setter, invoke)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1005, in _notify_change
#     self._trigger_on_change(event)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1095, in _trigger_on_change
#     self._with_self_as_curdoc(event.callback_invoker)
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/document/document.py", line 1113, in _with_self_as_curdoc
#     return f()
#   File "/home/andrea/devel/rfx/rfx-hunch/build/conf/python/site-packages/lib/python3.6/site-packages/bokeh/util/callback_manager.py", line 159, in invoke
#     callback(attr, old, new)
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in posx_cb
#     x,y = [float(x.strip()) for x in new.split(',')]
#   File "/home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/Hunch_lsplot.py", line 121, in <listcomp>
#     x,y = [float(x.strip()) for x in new.split(',')]
# ValueError: could not convert string to float: '2.527undefined'

# %%
models.base.train_thread(m, data=ds, epoch=5, batch=200, learning_rate=1e-3).control_panel()
# m.save('kcp/step2_t1')
# m.load('kcp/step2_t1')
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/5
# 200/200 [==============================] - 9s 45ms/step - loss: 0.0149
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# Epoch 2/5
# 153/200 [=====================>........] - ETA: 1s - loss: 0.0047

# %%
def simulate_missing_data(m, lpt=[0.5,-1.6], noise_var=0.05, arr = [3,2,1,5,8,7,6,9,12,11,14,13,18]):
    xy = m.decode(tf.convert_to_tensor([pt]),apply_sigmoid=True, training=False)
    x,y = tf.split(xy[0], 2)
    x,y = (x.numpy(), y.numpy())

    fig = plt.figure('gen_missing_curve',figsize=(18, 6))
    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)    
    
    ax1.set_xlim(-2.,2.)
    ax1.set_ylim(-2.,2.)
    
    ax1.scatter(pt[0],pt[1],s=80)
    ax2.scatter(x,y,s=40)

    # apply noise
    x += np.random.normal(0,noise_var,len(x))
    y += np.random.normal(0,noise_var,len(y))

    # apply missing data simulation
    for i,v in enumerate(arr,0):
        x[arr[i]]=x[arr[i]+1]
        y[arr[i]]=y[arr[i]+1]
    
    ax2.scatter(x,y,s=80)

    me,va = m.encode(tf.reshape(tf.concat([x,y],0), shape=[1,-1]), training=False)
    print("Guessed Latent point = ",me.numpy())
    gpt = me[0].numpy()
    ax1.scatter(gpt[0],gpt[1])
    
    XY = m.decode(me,apply_sigmoid=True, training=False)
    X,Y = tf.split(XY[0], 2)
    X,Y = (X.numpy(), Y.numpy())
    # plt.figure('reconstructed')
    ax2.scatter(X,Y,s=40)
    # plt.plot(X,Y)

# %%
# generate from point: 0,0
pt = [0.0,0.0]
noise_var = 0.05
arr = [3,2,1,5,8,7,6,9,12,11,14,13,18]
simulate_missing_data(m,pt,noise_var,arr)
# Out:
# <img src="data:image/png;base64,..." width="1799.9999463558213">
# Guessed Latent point =  [[ 0.0304515  -0.01457697]]

# %%
# generate from point: -0.9,0
pt = [-0.9,0]
noise_var = 0.05
arr = [3,6,5,8,7,6,9,12,11,14,13,18]
simulate_missing_data(m,pt,noise_var,arr)
# Out:
# Guessed Latent point =  [[-1.3542733  0.0058396]]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# # TEST2: 2G Y-strafe

# %%
ds = dummy.Dummy_g1data(counts=40000)
ds.kinds =  [
    {'mean': [0.5], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [0.2]},
]
ds.buffer()
dummy.test_gendata(ds)
m = models.AEFIT.AEFIT(latent_dim=2, beta=1.)
# Out:
# AEFIT5 ready:

# %%
# aefit.test_dummy(m, data=ds2, epoch=5, batch=200, loss_factor=1e-3)
# m.save('kcp/step2_t2')
m.train(ds)
# m.load('kcp/step2_t2')
# Out:
# EPOCH:  0
# it: 155 - loss: 14.690154
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-82bed7bd5e48> in <module>()
#       1 # aefit.test_dummy(m, data=ds2, epoch=5, batch=200, loss_factor=1e-3)
#       2 # m.save('kcp/step2_t2')
# ----> 3 m.train(ds)
#       4 # m.load('kcp/step2_t2')
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/base.py in train(self, dataset, epoch, batch, learning_rate)
#      59             print('EPOCH: ',e)
#      60             for i,data in enumerate(dt.batch(batch, drop_remainder=True)):
# ---> 61                 loss = self.train_step(data)
#      62                 sys.stdout.write('it: %d - loss: %f \r'%(i,loss))
#      63                 if self.stop_training:
#
# /home/andrea/devel/rfx/rfx-hunch/src/Tprofile_read/models/AEFIT5.py in train_step(self, data, training)
#     219         with tf.GradientTape() as tape:
#     220             XY = self.call(xy, training=training)
# --> 221             loss = tf.reduce_mean( self.loss(xy, XY) + self.losses[0] )
#     222         if training:
#     223             gradients = tape.gradient(loss, self.trainable_variables)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in losses(self)
#     818       if loss_tensor is not None:
#     819         collected_losses.append(loss_tensor)
# --> 820     return collected_losses + self._gather_children_attribute('losses')
#     821
#     822   @doc_controls.for_subclass_implementers
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in _gather_children_attribute(self, attribute)
#    2109     if hasattr(self, '_layers'):
#    2110       nested_layers = trackable_layer_utils.filter_empty_layer_containers(
# -> 2111           self._layers)
#    2112       return list(
#    2113           itertools.chain.from_iterable(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/layer_utils.py in filter_empty_layer_containers(layer_list)
#      53     if is_layer(obj):
#      54       filtered.append(obj)
# ---> 55     elif hasattr(obj, "layers"):
#      56       # Trackable data structures will not show up in ".layers" lists, but
#      57       # the layers they contain will.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/data_structures.py in layers(self)
#     186   @property
#     187   def layers(self):
# --> 188     return layer_utils.filter_empty_layer_containers(self._layers)
#     189
#     190   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/data_structures.py in _layers(self)
#     180       if (isinstance(obj, TrackableDataStructure)
#     181           or layer_utils.is_layer(obj)
# --> 182           or layer_utils.has_weights(obj)):
#     183         collected.append(obj)
#     184     return collected
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/layer_utils.py in has_weights(obj)
#      31
#      32
# ---> 33 def has_weights(obj):
#      34   """Implicit check for Layer-like objects."""
#      35   # TODO(b/110718070): Replace with isinstance(obj, base_layer.Layer).
#
# KeyboardInterrupt:

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(m)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11138">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11426">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:32907/autoload.js?bokeh-autoload-element=11427&bokeh-absolute-url=http://172.17.0.2:32907&resources=none" id="11427"></script>

# %%
# generate from point: 0,-0.5
pt = [0,-0.5]
noise_var = 0.05
arr = [3,6,5,8,7,6,9,12,11,14,13,18]
simulate_missing_data(m,pt,noise_var,arr)

# %% [markdown]
# # 7G X-strafe

# %%
ds = dummy.Dummy_g1data(counts=60000)
ds.kinds =  [
    {'mean': [0.8], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [0.5]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [0.5]},    
]

dummy.test_gendata(ds)
m = aefit.AEFIT(latent_dim=2)

# %%
# aefit.test_dummy(m, data=ds, epoch=5, batch=200, loss_factor=1e-3)
# m.save('kcp/step2_t3')
m.load('kcp/step2_t3')

# %%
from bokeh.io import show, output_notebook
output_notebook()

p = Hplt.LSPlotBokeh()
p.set_model(m)
p.set_data(ds)
p.plot(notebook_url='http://172.17.0.2:8888')

# %% [markdown]
# # 7+7G XY-strafe

# %%
ds = dummy.Dummy_g1data(counts=60000)
ds.kinds =  [
    {'mean': [0.8], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [0.2]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [0.2]},    

    {'mean': [0.8], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.7], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.6], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.5], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.4], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.3], 'sigma': [0.1], 'gain': [1.]},
    {'mean': [0.2], 'sigma': [0.1], 'gain': [1.]},    
]
ds.buffer()
dummy.test_gendata(ds)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# aefit.test_dummy(m, data=ds, epoch=5, batch=200, loss_factor=1e-3)
models.base.train_thread(m, data=ds, epoch=5, batch=200, learning_rate=1e-3).control_panel()
# m.save('kcp/step2_t4')
# m.load('kcp/step2_t4')
# Out:
# WARNING: no lenght of dataset provided
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/5
# 300/300 [==============================] - 21s 69ms/step - loss: 14.6984 - accuracy: 0.6905 - sce: 14.6984 - akl: 54.7769 - kld: 32.0323 - v_mea: 3.5475 - v_std: 0.0052
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# Epoch 2/5
# 300/300 [==============================] - 21s 69ms/step - loss: 14.4920 - accuracy: 0.6952 - sce: 14.4920 - akl: 58.2951 - kld: 34.9069 - v_mea: 3.2888 - v_std: 0.0018
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000729000034625642.
# Epoch 3/5
# 244/300 [=======================>......] - ETA: 4s - loss: 14.4539 - accuracy: 0.6966 - sce: 14.4539 - akl: 62.6394 - kld: 37.1994 - v_mea: 3.2818 - v_std: 0.0012

# %%
if INTERACTIVE:
    p = Hplt.LSPlotBokeh()
    p.set_model(m)
    p.set_data(ds)
    p.plot(notebook_url='http://172.17.0.2:8888')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="14269">Loading BokehJS ...</span>
#     </div>
# <script src="http://172.17.0.2:40507/autoload.js?bokeh-autoload-element=14270&bokeh-absolute-url=http://172.17.0.2:40507&resources=none" id="14270"></script>
